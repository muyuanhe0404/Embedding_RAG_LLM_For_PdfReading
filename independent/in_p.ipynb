# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/independent/
# !ls
# !python3 in_p.py
# Out:
# /content/drive/MyDrive/independent

# %%
# !pip install pdfminer.six faiss-cpu sentence-transformers transformers accelerate bitsandbytes

# %%
# !pip install jupyter nbconvert fastapi[all] "uvicorn[standard]" pyngrok nest-asyncio

# %%
from fastapi.testclient import TestClient
import main
import pprint

# spin up the app
client = TestClient(main.app)

# hit the /ask endpoint
resp = client.post(
    "/ask",
    json={"question": "What are the major symbols in The Great Gatsby?"}
)

# inspect status
print("Status:", resp.status_code)

# pretty-print the JSON body
pprint.pprint(resp.json(), width=120)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Status: 200
# {'items': [{'analysis': 'The green light represents Gatsby’s yearning for Daisy and the promise of a newer future. It '
#                         'also embodies the larger American Dream, highlighting the theme of idealism versus reality.',
#             'description': 'A beacon at the end of Daisy’s dock symbolizing hope and aspiration.',
#             'key_quote': 'He stretched out his arms toward the dark water in a curious way and far as I was from him I '
#                          'could have sworn he was trembling. Involuntarily I glanced seaward—and distinguished nothing '
#                          'except a single green light, minute and far away, that might have been the end of a dock.',
#             'name': 'The Green Light',
#             'page_references': [{'label': 'Initial mention on Daisy’s dock', 'page': 23},
#                                 {'label': 'Gatsby’s reflective gaze', 'page': 91}],
#             'quote_page': 23},
#            {'analysis': 'The Valley of Ashes serves as a stark reminder of the consequences of unchecked ambition and '
#                         'the hollowness of material success. It underscores the stark divide between the wealthy elite '
#                         'and the impoverished working class.',
#             'description': 'A desolate wasteland symbolizing moral decay and social disparity.',
#             'key_quote': 'This is a valley of ashes—a fantastic farm where ashes grow like wheat into ridges and hills '
#                          'and grotesque gardens; where ashes take the forms of houses...',
#             'name': 'The Valley of Ashes',
#             'page_references': [{'label': 'Representation of decay', 'page': 27},
#                                 {'label': 'Significance in Myrtle’s tragedy', 'page': 156},
#                                 {'label': 'Nick’s reflection on its symbolism', 'page': 162}],
#             'quote_page': 27},
#            {'analysis': 'The eyes of Dr. T.J. Eckleburg represent a haunting presence watching over the characters, '
#                         'reflecting a loss of moral compass in the Jazz Age society. They stand as a judgmental but '
#                         'indifferent observer of the characters’ actions and moral decay.',
#             'description': 'Giant, looming eyes on a billboard symbolizing moral oversight and the decline of values.',
#             'key_quote': 'But his eyes, dimmed a little by many paintless days under sun and rain, brood on over the '
#                          'solemn dumping ground.',
#             'name': 'The Eyes of Dr. T.J. Eckleburg',
#             'page_references': [{'label': 'Introduction of Eckleburg’s eyes', 'page': 27},
#                                 {'label': 'Myrtle’s death scene', 'page': 167},
#                                 {'label': 'Discussion of faded eyes', 'page': 159}],
#             'quote_page': 27},
#            {'analysis': 'The color gold throughout the novel is associated with opulence, extravagance, and the '
#                         'superficiality of the Jazz Age. It represents the glamorous facade that masks deeper issues '
#                         'of moral corruption and disillusionment.',
#             'description': 'Symbolizing wealth, excess, and the allure of material success.',
#             'key_quote': 'Then wear the gold hat, if that will move her; If you can bounce high, bounce for her too...',
#             'name': 'The Color Gold',
#             'page_references': [{'label': 'Introduction of the gold hat', 'page': 3},
#                                 {'label': 'Reflections on materialism', 'page': 125},
#                                 {'label': 'Association with Gatsby’s parties', 'page': 47}],
#             'quote_page': 3},
#            {'analysis': 'White is used to convey a sense of purity and innocence, often juxtaposed against the '
#                         "characters' moral ambiguity. It also symbolizes the facade of perfection that masks the "
#                         "characters' hidden flaws and deceit.",
#             'description': 'Symbolizing purity, innocence, and the facade of perfection.',
#             'key_quote': 'I wanted no more riotous excursions with privileged glimpses into the human heart. Only '
#                          'Gatsby, the man who gives his name to this book, was exempt from my reaction...',
#             'name': 'The Color White',
#             'page_references': [{'label': "Nick's reflection on Gatsby", 'page': 5},
#                                 {'label': "Discussion of Gatsby's allure", 'page': 91},
#                                 {'label': 'Contrast with other characters', 'page': 23}],
#             'quote_page': 5}],
#  'subtitle': 'Exploring significant symbols and motifs throughout the novel.',
#  'title': 'Key Symbols in The Great Gatsby'}

# %%
import subprocess, time
from google.colab import userdata
subprocess.Popen([
    "uvicorn", "main:app",
    "--host", "0.0.0.0",
    "--port", "8000",
    "--loop", "asyncio"     # force asyncio loop so no nest_asyncio needed
])
time.sleep(5)

# Configure and reset ngrok
from pyngrok import ngrok
token = userdata.get('NGROK_AUTH_TOKEN')
if not token:
    raise RuntimeError("NGROK_AUTH_TOKEN missing in userdata")
ngrok.set_auth_token(token)
ngrok.kill()  # close old tunnels


public_url = ngrok.connect(8000).public_url
print("🚀 Your demo is live at:", public_url)
# Out:
# 🚀 Your demo is live at: https://fdb4-34-121-186-127.ngrok-free.app
