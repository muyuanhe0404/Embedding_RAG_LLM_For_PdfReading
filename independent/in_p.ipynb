# %%
# !pip install pdfminer.six faiss-cpu sentence-transformers transformers accelerate bitsandbytes

# %%
# !pip install jupyter nbconvert fastapi[all] "uvicorn[standard]" pyngrok nest-asyncio

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/independent/
# !ls
# !python3 in_p.py
# Out:
# /content/drive/MyDrive/independent
# chunks.pkl	    index.html	in_p.py  __pycache__  the-great-gatsby.pdf
# gatsby_index.faiss  in_p.ipynb	main.py  style.css
# 2025-04-26 12:35:54.942638: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-26 12:35:54.962460: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745670954.988008    3117 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745670954.996141    3117 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-26 12:35:55.020861: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# modules.json: 100% 229/229 [00:00<00:00, 1.99MB/s]
# config_sentence_transformers.json: 100% 122/122 [00:00<00:00, 728kB/s]
# README.md: 100% 3.51k/3.51k [00:00<00:00, 27.3MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 455kB/s]
# config.json: 100% 629/629 [00:00<00:00, 4.83MB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors: 100% 90.9M/90.9M [00:00<00:00, 432MB/s]
# tokenizer_config.json: 100% 314/314 [00:00<00:00, 2.18MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 550kB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 2.07MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 993kB/s]
# config.json: 100% 190/190 [00:00<00:00, 2.07MB/s]
# Batches: 100% 4/4 [00:00<00:00,  5.85it/s]
# Saved 125 chunks and FAISS index.
# config.json: 100% 614/614 [00:00<00:00, 5.10MB/s]
# model.safetensors.index.json: 100% 26.8k/26.8k [00:00<00:00, 110MB/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0% 0.00/3.50G [00:00<?, ?B/s]
#
# model-00001-of-00002.safetensors:   0% 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0% 10.5M/3.50G [00:00<00:42, 81.4MB/s]
#
# model-00001-of-00002.safetensors:   0% 31.5M/9.98G [00:00<00:34, 288MB/s]
# model-00002-of-00002.safetensors:   1% 31.5M/3.50G [00:00<00:25, 136MB/s]
#
# model-00001-of-00002.safetensors:   1% 73.4M/9.98G [00:00<00:28, 343MB/s]
# model-00002-of-00002.safetensors:   2% 62.9M/3.50G [00:00<00:16, 206MB/s]
#
# model-00001-of-00002.safetensors:   1% 115M/9.98G [00:00<00:26, 369MB/s]
# model-00002-of-00002.safetensors:   3% 105M/3.50G [00:00<00:12, 264MB/s]
#
# model-00001-of-00002.safetensors:   2% 157M/9.98G [00:00<00:26, 375MB/s]
# model-00002-of-00002.safetensors:   4% 147M/3.50G [00:00<00:11, 298MB/s]
#
# model-00001-of-00002.safetensors:   2% 199M/9.98G [00:00<00:25, 378MB/s]
# model-00002-of-00002.safetensors:   6% 199M/3.50G [00:00<00:09, 364MB/s]
#
# model-00001-of-00002.safetensors:   2% 241M/9.98G [00:00<00:25, 388MB/s]
#
# model-00001-of-00002.safetensors:   3% 294M/9.98G [00:00<00:23, 418MB/s]
# model-00002-of-00002.safetensors:   7% 252M/3.50G [00:00<00:08, 373MB/s]
#
# model-00001-of-00002.safetensors:   3% 346M/9.98G [00:00<00:22, 427MB/s]
# model-00002-of-00002.safetensors:   8% 294M/3.50G [00:00<00:09, 355MB/s]
#
# model-00001-of-00002.safetensors:   4% 398M/9.98G [00:01<00:23, 409MB/s]
# model-00002-of-00002.safetensors:  10% 336M/3.50G [00:01<00:09, 320MB/s]
#
# model-00001-of-00002.safetensors:   4% 440M/9.98G [00:01<00:23, 400MB/s]
# model-00002-of-00002.safetensors:  11% 377M/3.50G [00:01<00:09, 332MB/s]
#
# model-00001-of-00002.safetensors:   5% 482M/9.98G [00:01<00:23, 405MB/s]
# model-00002-of-00002.safetensors:  12% 419M/3.50G [00:01<00:09, 311MB/s]
#
# model-00001-of-00002.safetensors:   5% 535M/9.98G [00:01<00:22, 411MB/s]
#
# model-00001-of-00002.safetensors:   6% 577M/9.98G [00:01<00:23, 400MB/s]
# model-00002-of-00002.safetensors:  13% 461M/3.50G [00:01<00:09, 305MB/s]
#
# model-00001-of-00002.safetensors:   6% 629M/9.98G [00:01<00:22, 409MB/s]
# model-00002-of-00002.safetensors:  14% 503M/3.50G [00:01<00:09, 323MB/s]
#
# model-00001-of-00002.safetensors:   7% 682M/9.98G [00:01<00:22, 419MB/s]
# model-00002-of-00002.safetensors:  16% 545M/3.50G [00:01<00:08, 329MB/s]
#
# model-00001-of-00002.safetensors:   7% 724M/9.98G [00:01<00:22, 409MB/s]
# model-00002-of-00002.safetensors:  17% 587M/3.50G [00:01<00:08, 332MB/s]
#
# model-00001-of-00002.safetensors:   8% 765M/9.98G [00:01<00:23, 393MB/s]
# model-00002-of-00002.safetensors:  18% 640M/3.50G [00:02<00:07, 360MB/s]
#
# model-00001-of-00002.safetensors:   8% 807M/9.98G [00:02<00:23, 398MB/s]
# model-00002-of-00002.safetensors:  19% 682M/3.50G [00:02<00:07, 368MB/s]
#
# model-00001-of-00002.safetensors:   9% 849M/9.98G [00:02<00:22, 399MB/s]
# model-00002-of-00002.safetensors:  21% 724M/3.50G [00:02<00:07, 376MB/s]
#
# model-00001-of-00002.safetensors:   9% 912M/9.98G [00:02<00:20, 444MB/s]
# model-00002-of-00002.safetensors:  22% 765M/3.50G [00:02<00:07, 372MB/s]
#
# model-00001-of-00002.safetensors:  10% 965M/9.98G [00:02<00:23, 390MB/s]
# model-00002-of-00002.safetensors:  23% 807M/3.50G [00:02<00:07, 344MB/s]
#
# model-00001-of-00002.safetensors:  10% 1.01G/9.98G [00:02<00:23, 382MB/s]
# model-00002-of-00002.safetensors:  24% 849M/3.50G [00:02<00:07, 345MB/s]
# model-00002-of-00002.safetensors:  25% 891M/3.50G [00:02<00:07, 358MB/s]
#
# model-00001-of-00002.safetensors:  11% 1.06G/9.98G [00:02<00:22, 388MB/s]
#
# model-00001-of-00002.safetensors:  11% 1.10G/9.98G [00:02<00:23, 377MB/s]
# model-00002-of-00002.safetensors:  27% 933M/3.50G [00:02<00:07, 335MB/s]
# model-00002-of-00002.safetensors:  28% 975M/3.50G [00:03<00:08, 304MB/s]
#
# model-00001-of-00002.safetensors:  11% 1.14G/9.98G [00:03<00:31, 279MB/s]
# model-00002-of-00002.safetensors:  29% 1.02G/3.50G [00:03<00:07, 331MB/s]
#
# model-00001-of-00002.safetensors:  12% 1.20G/9.98G [00:03<00:27, 318MB/s]
# model-00002-of-00002.safetensors:  31% 1.07G/3.50G [00:03<00:06, 362MB/s]
#
# model-00001-of-00002.safetensors:  12% 1.24G/9.98G [00:03<00:28, 304MB/s]
# model-00002-of-00002.safetensors:  32% 1.11G/3.50G [00:03<00:08, 293MB/s]
#
# model-00001-of-00002.safetensors:  13% 1.28G/9.98G [00:03<00:30, 288MB/s]
# model-00002-of-00002.safetensors:  33% 1.15G/3.50G [00:03<00:10, 229MB/s]
#
# model-00001-of-00002.safetensors:  13% 1.31G/9.98G [00:03<00:39, 217MB/s]
# model-00002-of-00002.safetensors:  34% 1.18G/3.50G [00:03<00:09, 243MB/s]
#
# model-00001-of-00002.safetensors:  14% 1.35G/9.98G [00:03<00:35, 241MB/s]
# model-00002-of-00002.safetensors:  35% 1.22G/3.50G [00:04<00:12, 184MB/s]
#
# model-00001-of-00002.safetensors:  14% 1.38G/9.98G [00:04<00:48, 177MB/s]
# model-00002-of-00002.safetensors:  36% 1.25G/3.50G [00:04<00:11, 200MB/s]
#
# model-00001-of-00002.safetensors:  14% 1.42G/9.98G [00:04<00:52, 162MB/s]
# model-00002-of-00002.safetensors:  37% 1.28G/3.50G [00:04<00:12, 173MB/s]
#
# model-00001-of-00002.safetensors:  14% 1.44G/9.98G [00:04<01:01, 140MB/s]
# model-00002-of-00002.safetensors:  37% 1.30G/3.50G [00:04<00:15, 143MB/s]
#
# model-00001-of-00002.safetensors:  15% 1.46G/9.98G [00:04<01:14, 114MB/s]
# model-00002-of-00002.safetensors:  38% 1.32G/3.50G [00:05<00:19, 113MB/s]
#
# model-00001-of-00002.safetensors:  15% 1.50G/9.98G [00:05<00:56, 151MB/s]
# model-00002-of-00002.safetensors:  39% 1.35G/3.50G [00:05<00:15, 141MB/s]
#
# model-00001-of-00002.safetensors:  15% 1.52G/9.98G [00:05<00:53, 158MB/s]
# model-00002-of-00002.safetensors:  40% 1.38G/3.50G [00:05<00:13, 156MB/s]
#
# model-00001-of-00002.safetensors:  16% 1.55G/9.98G [00:05<00:49, 169MB/s]
# model-00002-of-00002.safetensors:  40% 1.41G/3.50G [00:05<00:13, 159MB/s]
#
# model-00001-of-00002.safetensors:  16% 1.57G/9.98G [00:05<00:51, 162MB/s]
# model-00002-of-00002.safetensors:  41% 1.43G/3.50G [00:05<00:13, 154MB/s]
#
# model-00001-of-00002.safetensors:  16% 1.59G/9.98G [00:05<00:55, 151MB/s]
# model-00002-of-00002.safetensors:  41% 1.45G/3.50G [00:05<00:14, 144MB/s]
#
# model-00001-of-00002.safetensors:  16% 1.61G/9.98G [00:05<00:59, 140MB/s]
# model-00002-of-00002.safetensors:  42% 1.47G/3.50G [00:05<00:14, 136MB/s]
#
# model-00001-of-00002.safetensors:  16% 1.64G/9.98G [00:06<01:03, 132MB/s]
# model-00002-of-00002.safetensors:  43% 1.49G/3.50G [00:06<00:15, 129MB/s]
#
# model-00001-of-00002.safetensors:  17% 1.66G/9.98G [00:06<01:06, 125MB/s]
# model-00002-of-00002.safetensors:  43% 1.51G/3.50G [00:06<00:16, 122MB/s]
#
# model-00001-of-00002.safetensors:  17% 1.68G/9.98G [00:06<01:09, 119MB/s]
# model-00002-of-00002.safetensors:  44% 1.53G/3.50G [00:06<00:16, 117MB/s]
#
# model-00001-of-00002.safetensors:  17% 1.70G/9.98G [00:06<01:13, 113MB/s]
# model-00002-of-00002.safetensors:  44% 1.55G/3.50G [00:06<00:17, 111MB/s]
#
# model-00001-of-00002.safetensors:  17% 1.72G/9.98G [00:06<01:16, 108MB/s]
# model-00002-of-00002.safetensors:  45% 1.57G/3.50G [00:06<00:17, 107MB/s]
#
# model-00001-of-00002.safetensors:  17% 1.74G/9.98G [00:07<01:18, 104MB/s]
# model-00002-of-00002.safetensors:  46% 1.59G/3.50G [00:07<00:17, 106MB/s]
#
# model-00001-of-00002.safetensors:  18% 1.76G/9.98G [00:07<01:11, 115MB/s]
# model-00002-of-00002.safetensors:  46% 1.61G/3.50G [00:07<00:16, 115MB/s]
#
# model-00001-of-00002.safetensors:  18% 1.78G/9.98G [00:07<01:08, 120MB/s]
# model-00002-of-00002.safetensors:  47% 1.64G/3.50G [00:07<00:15, 123MB/s]
#
# model-00001-of-00002.safetensors:  18% 1.80G/9.98G [00:07<01:07, 122MB/s]
# model-00002-of-00002.safetensors:  47% 1.66G/3.50G [00:07<00:14, 124MB/s]
#
# model-00001-of-00002.safetensors:  18% 1.82G/9.98G [00:07<01:08, 120MB/s]
# model-00002-of-00002.safetensors:  48% 1.68G/3.50G [00:07<00:15, 121MB/s]
#
# model-00001-of-00002.safetensors:  18% 1.85G/9.98G [00:07<01:12, 113MB/s]
# model-00002-of-00002.safetensors:  49% 1.70G/3.50G [00:08<00:16, 112MB/s]
#
# model-00001-of-00002.safetensors:  19% 1.87G/9.98G [00:08<01:16, 106MB/s]
# model-00002-of-00002.safetensors:  49% 1.72G/3.50G [00:08<00:17, 101MB/s]
#
# model-00001-of-00002.safetensors:  19% 1.89G/9.98G [00:08<01:29, 90.7MB/s]
# model-00002-of-00002.safetensors:  50% 1.74G/3.50G [00:08<00:19, 91.7MB/s]
#
# model-00001-of-00002.safetensors:  19% 1.90G/9.98G [00:08<01:28, 91.8MB/s]
# model-00002-of-00002.safetensors:  50% 1.75G/3.50G [00:08<00:18, 93.7MB/s]
#
# model-00001-of-00002.safetensors:  19% 1.92G/9.98G [00:08<01:14, 108MB/s]
# model-00002-of-00002.safetensors:  51% 1.77G/3.50G [00:08<00:15, 108MB/s]
#
# model-00001-of-00002.safetensors:  19% 1.94G/9.98G [00:08<01:04, 125MB/s]
# model-00002-of-00002.safetensors:  51% 1.79G/3.50G [00:08<00:13, 128MB/s]
#
# model-00001-of-00002.safetensors:  20% 1.97G/9.98G [00:08<00:49, 160MB/s]
# model-00002-of-00002.safetensors:  52% 1.82G/3.50G [00:08<00:10, 166MB/s]
#
# model-00001-of-00002.safetensors:  20% 2.02G/9.98G [00:09<00:32, 242MB/s]
# model-00002-of-00002.safetensors:  53% 1.87G/3.50G [00:09<00:07, 215MB/s]
#
# model-00001-of-00002.safetensors:  21% 2.08G/9.98G [00:09<00:26, 300MB/s]
# model-00002-of-00002.safetensors:  55% 1.91G/3.50G [00:09<00:06, 256MB/s]
#
# model-00001-of-00002.safetensors:  21% 2.13G/9.98G [00:09<00:23, 341MB/s]
# model-00002-of-00002.safetensors:  56% 1.96G/3.50G [00:09<00:05, 305MB/s]
#
# model-00001-of-00002.safetensors:  22% 2.18G/9.98G [00:09<00:20, 377MB/s]
# model-00002-of-00002.safetensors:  57% 2.00G/3.50G [00:09<00:04, 330MB/s]
#
# model-00001-of-00002.safetensors:  22% 2.23G/9.98G [00:09<00:19, 399MB/s]
# model-00002-of-00002.safetensors:  58% 2.04G/3.50G [00:09<00:04, 342MB/s]
#
# model-00001-of-00002.safetensors:  23% 2.29G/9.98G [00:09<00:18, 414MB/s]
# model-00002-of-00002.safetensors:  60% 2.10G/3.50G [00:09<00:03, 375MB/s]
#
# model-00001-of-00002.safetensors:  23% 2.34G/9.98G [00:09<00:17, 435MB/s]
# model-00002-of-00002.safetensors:  61% 2.14G/3.50G [00:09<00:03, 386MB/s]
#
# model-00001-of-00002.safetensors:  24% 2.39G/9.98G [00:09<00:16, 451MB/s]
# model-00002-of-00002.safetensors:  62% 2.18G/3.50G [00:09<00:03, 386MB/s]
#
# model-00001-of-00002.safetensors:  24% 2.44G/9.98G [00:09<00:16, 465MB/s]
# model-00002-of-00002.safetensors:  64% 2.23G/3.50G [00:10<00:03, 348MB/s]
#
# model-00001-of-00002.safetensors:  25% 2.50G/9.98G [00:10<00:25, 290MB/s]
# model-00002-of-00002.safetensors:  65% 2.28G/3.50G [00:10<00:04, 262MB/s]
#
# model-00001-of-00002.safetensors:  25% 2.54G/9.98G [00:10<00:25, 297MB/s]
# model-00002-of-00002.safetensors:  66% 2.31G/3.50G [00:10<00:05, 203MB/s]
#
# model-00001-of-00002.safetensors:  26% 2.58G/9.98G [00:10<00:36, 205MB/s]
# model-00002-of-00002.safetensors:  67% 2.34G/3.50G [00:10<00:06, 178MB/s]
#
# model-00001-of-00002.safetensors:  26% 2.62G/9.98G [00:10<00:30, 237MB/s]
# model-00002-of-00002.safetensors:  68% 2.38G/3.50G [00:10<00:05, 211MB/s]
#
# model-00001-of-00002.safetensors:  27% 2.66G/9.98G [00:11<00:33, 216MB/s]
# model-00002-of-00002.safetensors:  69% 2.41G/3.50G [00:11<00:06, 180MB/s]
#
# model-00001-of-00002.safetensors:  27% 2.69G/9.98G [00:11<00:44, 164MB/s]
# model-00002-of-00002.safetensors:  70% 2.44G/3.50G [00:11<00:07, 145MB/s]
#
# model-00001-of-00002.safetensors:  28% 2.75G/9.98G [00:11<00:33, 213MB/s]
# model-00002-of-00002.safetensors:  71% 2.50G/3.50G [00:11<00:05, 197MB/s]
#
# model-00001-of-00002.safetensors:  28% 2.79G/9.98G [00:11<00:36, 196MB/s]
# model-00002-of-00002.safetensors:  72% 2.53G/3.50G [00:11<00:05, 175MB/s]
#
# model-00001-of-00002.safetensors:  28% 2.83G/9.98G [00:11<00:32, 219MB/s]
# model-00002-of-00002.safetensors:  73% 2.56G/3.50G [00:12<00:04, 190MB/s]
#
# model-00001-of-00002.safetensors:  29% 2.88G/9.98G [00:12<00:29, 238MB/s]
# model-00002-of-00002.safetensors:  74% 2.60G/3.50G [00:12<00:04, 184MB/s]
#
# model-00001-of-00002.safetensors:  29% 2.92G/9.98G [00:12<00:28, 244MB/s]
# model-00002-of-00002.safetensors:  75% 2.63G/3.50G [00:12<00:06, 139MB/s]
#
# model-00001-of-00002.safetensors:  30% 2.95G/9.98G [00:12<00:42, 165MB/s]
# model-00002-of-00002.safetensors:  76% 2.67G/3.50G [00:12<00:04, 173MB/s]
#
# model-00001-of-00002.safetensors:  30% 2.99G/9.98G [00:13<00:53, 131MB/s]
# model-00002-of-00002.safetensors:  77% 2.71G/3.50G [00:13<00:06, 128MB/s]
#
# model-00001-of-00002.safetensors:  30% 3.04G/9.98G [00:13<00:39, 176MB/s]
# model-00002-of-00002.safetensors:  78% 2.75G/3.50G [00:13<00:04, 166MB/s]
# model-00002-of-00002.safetensors:  79% 2.78G/3.50G [00:17<00:26, 27.2MB/s]
#
# model-00001-of-00002.safetensors:  31% 3.07G/9.98G [00:17<03:51, 29.8MB/s]
# model-00002-of-00002.safetensors:  81% 2.82G/3.50G [00:17<00:17, 39.4MB/s]
#
# model-00001-of-00002.safetensors:  31% 3.12G/9.98G [00:17<02:32, 45.0MB/s]
#
# model-00001-of-00002.safetensors:  32% 3.18G/9.98G [00:17<01:44, 65.0MB/s]
# model-00002-of-00002.safetensors:  82% 2.86G/3.50G [00:17<00:11, 55.2MB/s]
# model-00002-of-00002.safetensors:  83% 2.90G/3.50G [00:17<00:07, 75.3MB/s]
#
# model-00001-of-00002.safetensors:  32% 3.23G/9.98G [00:17<01:16, 88.0MB/s]
# model-00002-of-00002.safetensors:  84% 2.94G/3.50G [00:17<00:06, 92.7MB/s]
#
# model-00001-of-00002.safetensors:  33% 3.27G/9.98G [00:17<01:00, 110MB/s]
# model-00002-of-00002.safetensors:  85% 2.97G/3.50G [00:17<00:04, 114MB/s]
#
# model-00001-of-00002.safetensors:  33% 3.31G/9.98G [00:17<00:48, 138MB/s]
# model-00002-of-00002.safetensors:  86% 3.02G/3.50G [00:17<00:03, 159MB/s]
#
# model-00001-of-00002.safetensors:  34% 3.37G/9.98G [00:17<00:36, 180MB/s]
# model-00002-of-00002.safetensors:  87% 3.06G/3.50G [00:17<00:02, 191MB/s]
#
# model-00001-of-00002.safetensors:  34% 3.42G/9.98G [00:17<00:29, 222MB/s]
# model-00002-of-00002.safetensors:  89% 3.10G/3.50G [00:18<00:01, 228MB/s]
#
# model-00001-of-00002.safetensors:  35% 3.46G/9.98G [00:18<00:25, 254MB/s]
# model-00002-of-00002.safetensors:  90% 3.16G/3.50G [00:18<00:01, 274MB/s]
#
# model-00001-of-00002.safetensors:  35% 3.51G/9.98G [00:18<00:22, 290MB/s]
# model-00002-of-00002.safetensors:  91% 3.20G/3.50G [00:18<00:01, 296MB/s]
#
# model-00001-of-00002.safetensors:  36% 3.55G/9.98G [00:18<00:20, 308MB/s]
# model-00002-of-00002.safetensors:  93% 3.24G/3.50G [00:18<00:00, 322MB/s]
#
# model-00001-of-00002.safetensors:  36% 3.60G/9.98G [00:18<00:19, 326MB/s]
# model-00002-of-00002.safetensors:  94% 3.28G/3.50G [00:18<00:00, 337MB/s]
#
# model-00001-of-00002.safetensors:  37% 3.65G/9.98G [00:18<00:17, 352MB/s]
# model-00002-of-00002.safetensors:  95% 3.33G/3.50G [00:18<00:00, 372MB/s]
#
# model-00001-of-00002.safetensors:  37% 3.69G/9.98G [00:18<00:17, 364MB/s]
# model-00002-of-00002.safetensors:  96% 3.38G/3.50G [00:18<00:00, 373MB/s]
#
# model-00001-of-00002.safetensors:  37% 3.73G/9.98G [00:18<00:17, 363MB/s]
# model-00002-of-00002.safetensors:  98% 3.42G/3.50G [00:18<00:00, 371MB/s]
#
# model-00001-of-00002.safetensors:  38% 3.79G/9.98G [00:18<00:16, 386MB/s]
# model-00002-of-00002.safetensors:  99% 3.46G/3.50G [00:18<00:00, 368MB/s]
#
# model-00001-of-00002.safetensors:  38% 3.83G/9.98G [00:19<00:18, 328MB/s]
# model-00002-of-00002.safetensors: 100% 3.50G/3.50G [00:19<00:00, 183MB/s]
#
#
# model-00001-of-00002.safetensors:  39% 3.87G/9.98G [00:19<00:20, 301MB/s]
#
# model-00001-of-00002.safetensors:  39% 3.91G/9.98G [00:19<00:18, 323MB/s]
#
# model-00001-of-00002.safetensors:  40% 3.95G/9.98G [00:19<00:18, 329MB/s]
#
# model-00001-of-00002.safetensors:  40% 4.00G/9.98G [00:19<00:17, 349MB/s]
#
# model-00001-of-00002.safetensors:  40% 4.04G/9.98G [00:19<00:16, 364MB/s]
#
# model-00001-of-00002.safetensors:  41% 4.08G/9.98G [00:19<00:15, 377MB/s]
#
# model-00001-of-00002.safetensors:  41% 4.13G/9.98G [00:19<00:14, 405MB/s]
#
# model-00001-of-00002.safetensors:  42% 4.18G/9.98G [00:19<00:13, 424MB/s]
#
# model-00001-of-00002.safetensors:  42% 4.24G/9.98G [00:20<00:14, 390MB/s]
#
# model-00001-of-00002.safetensors:  43% 4.28G/9.98G [00:20<00:14, 390MB/s]
#
# model-00001-of-00002.safetensors:  43% 4.32G/9.98G [00:20<00:14, 392MB/s]
#
# model-00001-of-00002.safetensors:  44% 4.36G/9.98G [00:20<00:14, 383MB/s]
#
# model-00001-of-00002.safetensors:  44% 4.40G/9.98G [00:20<00:15, 370MB/s]
#
# model-00001-of-00002.safetensors:  45% 4.45G/9.98G [00:20<00:16, 335MB/s]
#
# model-00001-of-00002.safetensors:  45% 4.49G/9.98G [00:20<00:16, 323MB/s]
#
# model-00001-of-00002.safetensors:  45% 4.53G/9.98G [00:21<00:18, 288MB/s]
#
# model-00001-of-00002.safetensors:  46% 4.57G/9.98G [00:21<00:18, 297MB/s]
#
# model-00001-of-00002.safetensors:  46% 4.61G/9.98G [00:21<00:17, 307MB/s]
#
# model-00001-of-00002.safetensors:  47% 4.66G/9.98G [00:21<00:16, 319MB/s]
#
# model-00001-of-00002.safetensors:  47% 4.70G/9.98G [00:21<00:16, 327MB/s]
#
# model-00001-of-00002.safetensors:  48% 4.74G/9.98G [00:21<00:23, 219MB/s]
#
# model-00001-of-00002.safetensors:  48% 4.79G/9.98G [00:22<00:19, 271MB/s]
#
# model-00001-of-00002.safetensors:  49% 4.84G/9.98G [00:22<00:16, 314MB/s]
#
# model-00001-of-00002.safetensors:  49% 4.90G/9.98G [00:22<00:14, 349MB/s]
#
# model-00001-of-00002.safetensors:  50% 4.94G/9.98G [00:22<00:14, 353MB/s]
#
# model-00001-of-00002.safetensors:  50% 4.99G/9.98G [00:22<00:13, 376MB/s]
#
# model-00001-of-00002.safetensors:  50% 5.03G/9.98G [00:22<00:13, 378MB/s]
#
# model-00001-of-00002.safetensors:  51% 5.08G/9.98G [00:22<00:15, 318MB/s]
#
# model-00001-of-00002.safetensors:  51% 5.12G/9.98G [00:22<00:16, 296MB/s]
#
# model-00001-of-00002.safetensors:  52% 5.16G/9.98G [00:23<00:15, 310MB/s]
#
# model-00001-of-00002.safetensors:  52% 5.20G/9.98G [00:23<00:14, 325MB/s]
#
# model-00001-of-00002.safetensors:  53% 5.24G/9.98G [00:23<00:14, 327MB/s]
#
# model-00001-of-00002.safetensors:  53% 5.30G/9.98G [00:23<00:13, 357MB/s]
#
# model-00001-of-00002.safetensors:  54% 5.35G/9.98G [00:23<00:11, 386MB/s]
#
# model-00001-of-00002.safetensors:  54% 5.40G/9.98G [00:23<00:11, 385MB/s]
#
# model-00001-of-00002.safetensors:  55% 5.45G/9.98G [00:23<00:11, 401MB/s]
#
# model-00001-of-00002.safetensors:  55% 5.51G/9.98G [00:23<00:10, 413MB/s]
#
# model-00001-of-00002.safetensors:  56% 5.56G/9.98G [00:24<00:10, 423MB/s]
#
# model-00001-of-00002.safetensors:  56% 5.61G/9.98G [00:24<00:10, 431MB/s]
#
# model-00001-of-00002.safetensors:  57% 5.66G/9.98G [00:24<00:09, 436MB/s]
#
# model-00001-of-00002.safetensors:  57% 5.71G/9.98G [00:24<00:10, 416MB/s]
#
# model-00001-of-00002.safetensors:  58% 5.77G/9.98G [00:24<00:10, 393MB/s]
#
# model-00001-of-00002.safetensors:  58% 5.81G/9.98G [00:24<00:11, 361MB/s]
#
# model-00001-of-00002.safetensors:  59% 5.86G/9.98G [00:24<00:10, 385MB/s]
#
# model-00001-of-00002.safetensors:  59% 5.90G/9.98G [00:24<00:10, 386MB/s]
#
# model-00001-of-00002.safetensors:  60% 5.96G/9.98G [00:25<00:10, 399MB/s]
#
# model-00001-of-00002.safetensors:  60% 6.01G/9.98G [00:25<00:09, 401MB/s]
#
# model-00001-of-00002.safetensors:  61% 6.05G/9.98G [00:25<00:10, 386MB/s]
#
# model-00001-of-00002.safetensors:  61% 6.10G/9.98G [00:25<00:09, 401MB/s]
#
# model-00001-of-00002.safetensors:  62% 6.14G/9.98G [00:25<00:10, 362MB/s]
#
# model-00001-of-00002.safetensors:  62% 6.19G/9.98G [00:25<00:10, 366MB/s]
#
# model-00001-of-00002.safetensors:  62% 6.23G/9.98G [00:25<00:10, 343MB/s]
#
# model-00001-of-00002.safetensors:  63% 6.28G/9.98G [00:25<00:10, 361MB/s]
#
# model-00001-of-00002.safetensors:  63% 6.33G/9.98G [00:26<00:09, 372MB/s]
#
# model-00001-of-00002.safetensors:  64% 6.38G/9.98G [00:26<00:09, 366MB/s]
#
# model-00001-of-00002.safetensors:  64% 6.42G/9.98G [00:26<00:09, 365MB/s]
#
# model-00001-of-00002.safetensors:  65% 6.47G/9.98G [00:26<00:08, 405MB/s]
#
# model-00001-of-00002.safetensors:  65% 6.51G/9.98G [00:26<00:08, 409MB/s]
#
# model-00001-of-00002.safetensors:  66% 6.55G/9.98G [00:26<00:08, 381MB/s]
#
# model-00001-of-00002.safetensors:  66% 6.60G/9.98G [00:26<00:08, 379MB/s]
#
# model-00001-of-00002.safetensors:  67% 6.64G/9.98G [00:26<00:08, 389MB/s]
#
# model-00001-of-00002.safetensors:  67% 6.69G/9.98G [00:26<00:07, 418MB/s]
#
# model-00001-of-00002.safetensors:  68% 6.74G/9.98G [00:27<00:07, 429MB/s]
#
# model-00001-of-00002.safetensors:  68% 6.79G/9.98G [00:27<00:08, 380MB/s]
#
# model-00001-of-00002.safetensors:  69% 6.85G/9.98G [00:27<00:07, 404MB/s]
#
# model-00001-of-00002.safetensors:  69% 6.89G/9.98G [00:27<00:07, 398MB/s]
#
# model-00001-of-00002.safetensors:  69% 6.93G/9.98G [00:27<00:07, 397MB/s]
#
# model-00001-of-00002.safetensors:  70% 6.98G/9.98G [00:27<00:07, 415MB/s]
#
# model-00001-of-00002.safetensors:  70% 7.03G/9.98G [00:27<00:07, 381MB/s]
#
# model-00001-of-00002.safetensors:  71% 7.07G/9.98G [00:27<00:08, 361MB/s]
#
# model-00001-of-00002.safetensors:  71% 7.11G/9.98G [00:28<00:08, 348MB/s]
#
# model-00001-of-00002.safetensors:  72% 7.15G/9.98G [00:28<00:07, 361MB/s]
#
# model-00001-of-00002.safetensors:  72% 7.19G/9.98G [00:28<00:07, 370MB/s]
#
# model-00001-of-00002.safetensors:  73% 7.24G/9.98G [00:28<00:07, 362MB/s]
#
# model-00001-of-00002.safetensors:  73% 7.28G/9.98G [00:28<00:07, 376MB/s]
#
# model-00001-of-00002.safetensors:  73% 7.33G/9.98G [00:28<00:06, 401MB/s]
#
# model-00001-of-00002.safetensors:  74% 7.37G/9.98G [00:28<00:07, 360MB/s]
#
# model-00001-of-00002.safetensors:  74% 7.42G/9.98G [00:28<00:06, 394MB/s]
#
# model-00001-of-00002.safetensors:  75% 7.48G/9.98G [00:28<00:05, 421MB/s]
#
# model-00001-of-00002.safetensors:  75% 7.53G/9.98G [00:29<00:05, 442MB/s]
#
# model-00001-of-00002.safetensors:  76% 7.58G/9.98G [00:29<00:05, 456MB/s]
#
# model-00001-of-00002.safetensors:  77% 7.63G/9.98G [00:29<00:05, 459MB/s]
#
# model-00001-of-00002.safetensors:  77% 7.69G/9.98G [00:29<00:05, 441MB/s]
#
# model-00001-of-00002.safetensors:  78% 7.74G/9.98G [00:29<00:05, 405MB/s]
#
# model-00001-of-00002.safetensors:  78% 7.79G/9.98G [00:29<00:05, 422MB/s]
#
# model-00001-of-00002.safetensors:  79% 7.84G/9.98G [00:29<00:04, 432MB/s]
#
# model-00001-of-00002.safetensors:  79% 7.90G/9.98G [00:29<00:04, 440MB/s]
#
# model-00001-of-00002.safetensors:  80% 7.95G/9.98G [00:30<00:04, 454MB/s]
#
# model-00001-of-00002.safetensors:  80% 8.00G/9.98G [00:30<00:04, 454MB/s]
#
# model-00001-of-00002.safetensors:  81% 8.05G/9.98G [00:30<00:04, 449MB/s]
#
# model-00001-of-00002.safetensors:  81% 8.11G/9.98G [00:30<00:04, 428MB/s]
#
# model-00001-of-00002.safetensors:  82% 8.16G/9.98G [00:30<00:04, 430MB/s]
#
# model-00001-of-00002.safetensors:  82% 8.21G/9.98G [00:30<00:03, 449MB/s]
#
# model-00001-of-00002.safetensors:  83% 8.27G/9.98G [00:30<00:03, 472MB/s]
#
# model-00001-of-00002.safetensors:  84% 8.34G/9.98G [00:30<00:03, 491MB/s]
#
# model-00001-of-00002.safetensors:  84% 8.40G/9.98G [00:30<00:03, 502MB/s]
#
# model-00001-of-00002.safetensors:  85% 8.45G/9.98G [00:31<00:03, 494MB/s]
#
# model-00001-of-00002.safetensors:  85% 8.50G/9.98G [00:31<00:02, 491MB/s]
#
# model-00001-of-00002.safetensors:  86% 8.56G/9.98G [00:31<00:02, 474MB/s]
#
# model-00001-of-00002.safetensors:  86% 8.61G/9.98G [00:31<00:03, 450MB/s]
#
# model-00001-of-00002.safetensors:  87% 8.66G/9.98G [00:31<00:02, 456MB/s]
#
# model-00001-of-00002.safetensors:  87% 8.71G/9.98G [00:31<00:02, 454MB/s]
#
# model-00001-of-00002.safetensors:  88% 8.77G/9.98G [00:31<00:02, 449MB/s]
#
# model-00001-of-00002.safetensors:  88% 8.82G/9.98G [00:31<00:02, 459MB/s]
#
# model-00001-of-00002.safetensors:  89% 8.87G/9.98G [00:32<00:02, 450MB/s]
#
# model-00001-of-00002.safetensors:  89% 8.92G/9.98G [00:32<00:02, 457MB/s]
#
# model-00001-of-00002.safetensors:  90% 8.98G/9.98G [00:32<00:02, 469MB/s]
#
# model-00001-of-00002.safetensors:  90% 9.03G/9.98G [00:32<00:01, 478MB/s]
#
# model-00001-of-00002.safetensors:  91% 9.08G/9.98G [00:32<00:02, 443MB/s]
#
# model-00001-of-00002.safetensors:  92% 9.14G/9.98G [00:32<00:01, 467MB/s]
#
# model-00001-of-00002.safetensors:  92% 9.20G/9.98G [00:32<00:01, 419MB/s]
#
# model-00001-of-00002.safetensors:  93% 9.25G/9.98G [00:33<00:02, 333MB/s]
#
# model-00001-of-00002.safetensors:  93% 9.29G/9.98G [00:33<00:02, 311MB/s]
#
# model-00001-of-00002.safetensors:  94% 9.34G/9.98G [00:33<00:01, 346MB/s]
#
# model-00001-of-00002.safetensors:  94% 9.38G/9.98G [00:33<00:01, 359MB/s]
#
# model-00001-of-00002.safetensors:  94% 9.43G/9.98G [00:33<00:01, 345MB/s]
#
# model-00001-of-00002.safetensors:  95% 9.47G/9.98G [00:33<00:01, 330MB/s]
#
# model-00001-of-00002.safetensors:  95% 9.51G/9.98G [00:33<00:01, 332MB/s]
#
# model-00001-of-00002.safetensors:  96% 9.55G/9.98G [00:33<00:01, 329MB/s]
#
# model-00001-of-00002.safetensors:  96% 9.59G/9.98G [00:34<00:01, 338MB/s]
#
# model-00001-of-00002.safetensors:  97% 9.65G/9.98G [00:34<00:00, 379MB/s]
#
# model-00001-of-00002.safetensors:  97% 9.70G/9.98G [00:34<00:00, 412MB/s]
#
# model-00001-of-00002.safetensors:  98% 9.75G/9.98G [00:34<00:00, 407MB/s]
#
# model-00001-of-00002.safetensors:  98% 9.80G/9.98G [00:34<00:00, 422MB/s]
#
# model-00001-of-00002.safetensors:  99% 9.86G/9.98G [00:34<00:00, 438MB/s]
#
# model-00001-of-00002.safetensors:  99% 9.91G/9.98G [00:34<00:00, 447MB/s]
#
# model-00001-of-00002.safetensors: 100% 9.98G/9.98G [00:34<00:00, 286MB/s]
# Fetching 2 files: 100% 2/2 [00:35<00:00, 17.62s/it]
# Loading checkpoint shards: 100% 2/2 [00:16<00:00,  8.17s/it]
# generation_config.json: 100% 188/188 [00:00<00:00, 1.64MB/s]
# tokenizer_config.json: 100% 1.62k/1.62k [00:00<00:00, 16.2MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 68.5MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 4.38MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 2.14MB/s]
# Device set to use cuda:0
# config.json: 100% 794/794 [00:00<00:00, 6.58MB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors: 100% 90.9M/90.9M [00:00<00:00, 456MB/s]
# tokenizer_config.json: 100% 1.33k/1.33k [00:00<00:00, 10.7MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 526kB/s]
# tokenizer.json: 100% 711k/711k [00:00<00:00, 1.11MB/s]
# special_tokens_map.json: 100% 132/132 [00:00<00:00, 1.43MB/s]
# Q: What is the significance of the green light at the end of Daisy’s dock?
# A: The green light represents hope and the American Dream, symbolizing the possibility of attaining wealth and status through hard work and determination.
# → Time: 3.363 s
# --------------------------------------------------------------------------------
# Q: How does the Valley of Ashes illustrate the novel’s critique of moral decay?
# A: The Valley of Ashes symbolizes the corruption and moral bankruptcy that lies beneath the surface of society, representing the consequences of unchecked industrialization and materialism.
# → Time: 2.397 s
# --------------------------------------------------------------------------------
# Q: What role does Nick Carraway play as narrator, and how does his perspective shape the story?
# A: As the narrator, Nick provides an objective view of events unfolding around him, while also offering insightful commentary on the actions and motivations of characters. His Midwestern background and initial ske
# → Time: 2.558 s
# --------------------------------------------------------------------------------
# Q: In what ways does Daisy Buchanan embody both illusion and reality?
# A: Throughout The Great Gatsby, Daisy Buchanan embodies both illusion and reality, symbolizing the tension between the American Dream and the harsh realities of society
# → Time: 2.541 s
# --------------------------------------------------------------------------------
# Q: Why does Gatsby throw lavish parties, and what do they reveal about his character?
# A: Gatsby's parties reveal his desire for acceptance and belonging, as well as his ability to create a sense of community and connection among his guests. Despite his wealth and status, G
# → Time: 2.554 s
# --------------------------------------------------------------------------------

# %%
import subprocess, time
from google.colab import userdata
subprocess.Popen([
    "uvicorn", "main:app",
    "--host", "0.0.0.0",
    "--port", "8000",
    "--loop", "asyncio"     # force asyncio loop so no nest_asyncio needed
])
time.sleep(2)

# Configure and reset ngrok
from pyngrok import ngrok
token = userdata.get('NGROK_AUTH_TOKEN')
if not token:
    raise RuntimeError("NGROK_AUTH_TOKEN missing in userdata")
ngrok.set_auth_token(token)
ngrok.kill()  # close old tunnels

public_url = ngrok.connect(8000).public_url
print("🚀 Your demo is live at:", public_url)
# Out:
# 🚀 Your demo is live at: https://037b-34-87-160-81.ngrok-free.app

# %% [markdown]
# # RAG

# %%
import os
os.environ["TRANSFORMERS_NO_TF"] = "1"
DATA_DIR = '/content/drive/MyDrive/independent'
os.makedirs(DATA_DIR, exist_ok=True)
PDF_PATH = os.path.join(DATA_DIR, 'the-great-gatsby.pdf')

# %%
import pickle
from pdfminer.high_level import extract_text
from sentence_transformers import SentenceTransformer
import faiss

def load_pdf(path):
    return extract_text(path)

def chunk_text(text, chunk_size=500, overlap=100):
    tokens = text.split()
    chunks = []
    start = 0
    while start < len(tokens):
        chunks.append(" ".join(tokens[start:start+chunk_size]))
        start += chunk_size - overlap
    return chunks

def build_index(chunks, model_name='all-mpnet-base-v2'):
    model = SentenceTransformer(model_name, device='cuda')
    embeddings = model.encode(chunks, show_progress_bar=True, convert_to_numpy=True)
    idx = faiss.IndexFlatL2(embeddings.shape[1])
    idx.add(embeddings)
    return idx

text = load_pdf(PDF_PATH)
chunks = chunk_text(text)
index = build_index(chunks)
faiss.write_index(index, os.path.join(DATA_DIR, 'gatsby_index.faiss'))
with open(os.path.join(DATA_DIR, 'chunks.pkl'), 'wb') as f:
    pickle.dump(chunks, f)
print(f"Saved {len(chunks)} chunks and FAISS index.")

# %%
from google.colab import userdata
apikey = userdata.get('HUGGINGFACE_TOKEN')
from huggingface_hub import login
login(token=apikey)

import torch
from transformers import (
    BitsAndBytesConfig,
    AutoModelForCausalLM,
    AutoTokenizer,
    pipeline,
)


quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-2-7b-chat-hf",
    quantization_config=quant_config,
    device_map={"": "cuda:0"}
)

tokenizer = AutoTokenizer.from_pretrained(
    "meta-llama/Llama-2-7b-chat-hf",
    use_fast=False
)

generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=40,
    do_sample=True,
    top_k=50,
    top_p=0.9,
    temperature=0.7,
    repetition_penalty=1.1,
    return_full_text=False
)

# %%
import faiss
import pickle
from sentence_transformers import SentenceTransformer,CrossEncoder

index = faiss.read_index(os.path.join(DATA_DIR, 'gatsby_index.faiss'))
with open(os.path.join(DATA_DIR, 'chunks.pkl'), 'rb') as f:
    chunks = pickle.load(f)

embed_model   = SentenceTransformer('all-mpnet-base-v2', device='cuda')
cross_encoder = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2', device='cuda')

def retrieve(question: str, top_k: int = 5, fetch_k: int = 10):
    q_vec = embed_model.encode(question, convert_to_numpy=True)
    _, idxs = index.search(q_vec.reshape(1, -1), fetch_k)
    candidates = [chunks[i] for i in idxs[0]]
    scores = cross_encoder.predict([(question, txt) for txt in candidates])
    ranked = [txt for _, txt in sorted(zip(scores, candidates), reverse=True)]
    return ranked[:top_k]

def answer_rag(question: str, top_k: int = 5):
    docs = retrieve(question, top_k=top_k)
    context = "\n\n".join(d.replace("\n", " ") for d in docs)

    few_shot = """
Example:
Q: What does the Valley of Ashes symbolize in The Great Gatsby?
A: The Valley of Ashes symbolizes the moral decay lurking beneath the era’s glamour, representing the cost of unbridled industrial progress.

Example:
Q: How does Gatsby’s smile affect those around him?
A: Gatsby’s smile conveys both warmth and mystery, making others feel instantly at ease while also curious about the man behind it.

Now it’s your turn:
"""

    prompt = (
        few_shot +
        "Context:\n" + context + "\n\n" +
        f"Q: {question}\n" +
        "A:"
    )
    raw = generator(prompt)[0]['generated_text']

    # If the model echoed few‐shot, remove everything from the first example
    if "Example:" in raw:
        raw = raw.split("Example:")[0]

    # Only keep up through the first line break (in case it generated multiple lines)
    answer = raw.strip().split("\n")[0]

    return answer.strip()

# %%
test_questions = [
    "What is the significance of the green light at the end of Daisy’s dock?",
    "How does the Valley of Ashes illustrate the novel’s critique of moral decay?",
    "What role does Nick Carraway play as narrator, and how does his perspective shape the story?",
    "In what ways does Daisy Buchanan embody both illusion and reality?",
    "Why does Gatsby throw lavish parties, and what do they reveal about his character?",
    "How does Fitzgerald use the contrast between East Egg and West Egg to comment on social class?",
    "What does the billboard of Dr. T. J. Eckleburg’s eyes symbolize?",
    "How does the weather (sunshine, rain, heat) mirror the emotional tone of key scenes?",
    "What does Tom Buchanan represent in the context of wealth and power?",
    "How is the American Dream portrayed as both promise and illusion in the novel?",
    "What is the significance of Gatsby’s reunion with Daisy at Nick’s house?",
    "How does Myrtle Wilson’s fate underscore the novel’s themes of desire and destruction?"
]

for q in test_questions:
    print("Q:", q)
    try:
        answer = answer_rag(q)
    except Exception as e:
        answer = f"Error: {e}"
    print("A:", answer)
    print("-" * 80)
